# %%
# Import modules

import helpers as h
import pandas as pd
import json
import numpy as np
import os
import folium

# Load data

diphtheria = pd.read_csv('./data/disease/diphtheria.csv', header=1)
measles = pd.read_csv('./data/disease/measles.csv', header=1)
mumps = pd.read_csv('./data/disease/mumps.csv', header=1)
neonatal_tetanus = pd.read_csv('./data/disease/neonatal_tetanus.csv', header=1)
tuberculosis = pd.read_csv('./data/disease/tuberculosis.csv', header=1)

geo_path = 'maptest.json'
geo_data = json.load(open(geo_path))

# Fill NaN values with the value from the year before
diphtheria = diphtheria.bfill(axis=1).ffill(axis=1)
# diphtheria[diphtheria[' 2017'] > 100]

names_country = []
for i in np.arange(len(geo_data['features'])):
    names_country.append(geo_data['features'][i]['properties']['name'])
    
diphtheria.iloc[189,0] = 'Venezuela'
diphtheria.iloc[183,0] = 'United Kingdom'
diphtheria.iloc[184,0] = 'Tanzania'
diphtheria.iloc[21,0] = 'Bosnia and Herz.'
diphtheria.iloc[171,0] = 'Macedonia'
diphtheria.iloc[185,0] = 'United States'
diphtheria.iloc[190,0] = 'Vietnam'
diphtheria.iloc[47,0] = 'Dem. Rep. Congo'
diphtheria.iloc[46,0] = 'Dem. Rep. Korea'
diphtheria.iloc[45,0] = 'Czech Rep.'
diphtheria.iloc[20,0] = 'Bolivia'
diphtheria.iloc[80,0] = 'Iran'
diphtheria.iloc[93,0] = 'Lao PDR'
# print(names_country)
# Out:
# 60       Fiji
# 61    Finland
# 62     France
# 63      Gabon
# 64     Gambia
# 65    Georgia
# 66    Germany
# 67      Ghana
# 68     Greece
# 69    Grenada
# Name: Country, dtype: object

# %%
# Need to attach the percentages of incidence rate to the disease dataframes
# Load data for population, and append to disease dataframes
population = pd.read_csv('./data/population.csv', header=2)
population.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965     ...       \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     ...
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0     ...
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0     ...
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0     ...
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     ...
#
#          2009        2010        2011        2012        2013        2014  \
# ...

# %%
world_map = folium.Map(tiles='Stamen Terrain', zoom_start=7)
# world_map.choropleth(geo_data=geo_data)

world_map.choropleth(geo_data = geo_data,
                    name='choropleth',
                    data=diphtheria,
                    columns=['Country', ' 1980'],
                    key_on = 'feature.properties.name',
                    fill_color='YlOrRd',
                    fill_opacity=0.7,
                    line_opacity=0.2,
                    legend_name='2017 Diptheria')

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
